# %%
from __future__ import absolute_import, division, print_function

import tensorflow as tf
tf.enable_eager_execution()

import numpy as np
import os
import time
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
tweets = pd.read_csv('/content/gdrive/My Drive/for_tensorflow.csv')

# %%
tweets.head()
# Out:
#                                                clean
# 0  rais hand question jr ranger club member get e...
# 1  better way kick vacat settl watch win move 2nd...
# 2  proud announc today multi-year panership globe...
# 3  live radio thur may 30th today 4pm pt/7pm et a...
# 4  septemb retir nolan ryan ballpark arlington fi...

# %%
tweets.dropna(inplace=True)
tweets = tweets.reindex()

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

max_features = 3000
tokenizer = Tokenizer(num_words=max_features, split=' ')
tokenizer.fit_on_texts(tweets.clean)
# Out:
# Using TensorFlow backend.

# %%
X = tokenizer.texts_to_sequences(tweets.clean.astype(str))
X = pad_sequences(X)

# %%
word_dataset = tf.data.Dataset.from_tensor_slices(X)

# %%
word_dataset
# Out:
# <DatasetV1Adapter shapes: (18,), types: tf.int32>

# %%
vocab_size = len(tokenizer.word_index) + 1

# %%
seq_length = 128
sequences = word_dataset.batch(seq_length+1, drop_remainder=True)

# %%
def split_input_target(chunk):
    input_text = chunk[:-1]
    target_text = chunk[1:]
    return input_text, target_text

dataset = sequences.map(split_input_target)

# %%
# Batch size 
BATCH_SIZE = 128
examples_per_epoch = len(tweets)//seq_length
steps_per_epoch = 300

# # Buffer size to shuffle the dataset
# # (TF data is designed to work with possibly infinite sequences, 
# # so it doesn't attempt to shuffle the entire sequence in memory. Instead, 
# # it maintains a buffer in which it shuffles elements).
BUFFER_SIZE = 10000

dataset = dataset.shuffle(BUFFER_SIZE)

# dataset

# %%
dataset
# Out:
# <DatasetV1Adapter shapes: ((128, 18), (128, 18)), types: (tf.int32, tf.int32)>

# %%
n_cols = X.shape[1]


# The embedding dimension 
embedding_dim = 500

# Number of RNN units
rnn_units = 3072

# %%
def build_model(vocab_size, embedding_dim, rnn_units, batch_size):
    print (n_cols)
    model = tf.keras.Sequential([
     
    tf.keras.layers.Embedding(vocab_size, embedding_dim, 
                              batch_input_shape=[batch_size, None]),
    tf.keras.layers.LSTM(rnn_units,
        return_sequences=True, 
        recurrent_initializer='glorot_uniform',
        stateful=True),
    tf.keras.layers.LSTM(rnn_units,
        return_sequences=True, 
        recurrent_initializer='glorot_uniform',
        stateful=True),
    tf.keras.layers.LSTM(rnn_units,
        return_sequences=True, 
        recurrent_initializer='glorot_uniform',
        stateful=True),
    tf.keras.layers.Dense(vocab_size)
    ])
    return model

# %%
if tf.test.is_gpu_available():
    rnn = tf.keras.layers.CuDNNGRU
    print('GPU Running')
else:
    import functools
    rnn = functools.partial(
    tf.keras.layers.GRU, recurrent_activation='sigmoid')
    
model = build_model(
  vocab_size = vocab_size,
  embedding_dim=embedding_dim, 
  rnn_units=rnn_units,
  batch_size=BATCH_SIZE)
# Out:
# GPU Running
# 18

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (128, None, 500)          912000
# _________________________________________________________________
# cu_dnngru (CuDNNGRU)         (128, None, 3072)         32937984
# _________________________________________________________________
# cu_dnngru_1 (CuDNNGRU)       (128, None, 3072)         56641536
# _________________________________________________________________
# cu_dnngru_2 (CuDNNGRU)       (128, None, 3072)         56641536
# _________________________________________________________________
# dense (Dense)                (128, None, 1824)         5605152
# =================================================================
# Total params: 152,738,208
# Trainable params: 152,738,208
# Non-trainable params: 0
# _________________________________________________________________

# %%
def loss(labels, logits):
  return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

# %%
model.compile(
    optimizer = tf.train.AdamOptimizer(),
    loss = loss)

# %%
# Directory where the checkpoints will be saved
checkpoint_dir = '/content/gdrive/My Drive/training_checkpoints/complex'
# Name of the checkpoint files
checkpoint_prefix = os.path.join(checkpoint_dir, "weights.{epoch:02d}-{loss:.2f}")

checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    monitor='loss',
    save_weights_only=True,
    save_best_only=True)

# %%
EPOCHS=200

# %%
dataset
# Out:
# <DatasetV1Adapter shapes: ((128, 18), (128, 18)), types: (tf.int32, tf.int32)>

# %%
history = model.fit(dataset.repeat(), epochs=EPOCHS, steps_per_epoch=50, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/200
# 50/50 [==============================] - 48s 962ms/step - loss: 8.4450
# Epoch 2/200
# 50/50 [==============================] - 45s 907ms/step - loss: 4.9527
# Epoch 3/200
# 50/50 [==============================] - 46s 920ms/step - loss: 4.7850
# Epoch 4/200
# 50/50 [==============================] - 45s 899ms/step - loss: 4.6308
# Epoch 5/200
# 50/50 [==============================] - 47s 931ms/step - loss: 4.4954
# Epoch 6/200
# 50/50 [==============================] - 46s 926ms/step - loss: 4.3952
# Epoch 7/200
# 50/50 [==============================] - 46s 930ms/step - loss: 4.2688
# Epoch 8/200
# 50/50 [==============================] - 47s 931ms/step - loss: 4.2174
# Epoch 9/200
# 50/50 [==============================] - 47s 940ms/step - loss: 4.1375
# Epoch 10/200
# 50/50 [==============================] - 46s 917ms/step - loss: 4.0767
# Epoch 11/200
# 50/50 [==============================] - 45s 892ms/step - loss: 4.0430
# Epoch 12/200
# 50/50 [==============================] - 46s 921ms/step - loss: 3.9845
# Epoch 13/200
# 50/50 [==============================] - 46s 918ms/step - loss: 3.8739
# Epoch 14/200
# 50/50 [==============================] - 46s 917ms/step - loss: 3.7640
# Epoch 15/200
# 50/50 [==============================] - 46s 915ms/step - loss: 3.6277
# Epoch 16/200
# 50/50 [==============================] - 46s 914ms/step - loss: 3.5526
# Epoch 17/200
# 50/50 [==============================] - 46s 920ms/step - loss: 3.4505
# Epoch 18/200
# 50/50 [==============================] - 46s 916ms/step - loss: 3.3517
# Epoch 19/200
# 50/50 [==============================] - 46s 927ms/step - loss: 3.2768
# Epoch 20/200
# 50/50 [==============================] - 46s 923ms/step - loss: 3.2505
# Epoch 21/200
# 50/50 [==============================] - 46s 923ms/step - loss: 3.1600
# Epoch 22/200
# 50/50 [==============================] - 47s 932ms/step - loss: 3.1259
# Epoch 23/200
# 50/50 [==============================] - 32s 636ms/step - loss: 3.1265
# Epoch 24/200
# 50/50 [==============================] - 46s 916ms/step - loss: 3.0613
# Epoch 25/200
# 50/50 [==============================] - 47s 933ms/step - loss: 3.0398
# Epoch 26/200
# 50/50 [==============================] - 47s 930ms/step - loss: 2.9721
# Epoch 27/200
# 50/50 [==============================] - 46s 920ms/step - loss: 2.9177
# Epoch 28/200
# 50/50 [==============================] - 47s 930ms/step - loss: 2.9065
# Epoch 29/200
# 50/50 [==============================] - 46s 930ms/step - loss: 2.8534
# Epoch 30/200
# 50/50 [==============================] - 46s 926ms/step - loss: 2.8239
# Epoch 31/200
# 50/50 [==============================] - 46s 917ms/step - loss: 2.8061
# Epoch 32/200
# 50/50 [==============================] - 46s 917ms/step - loss: 2.7317
# Epoch 33/200
# 50/50 [==============================] - 46s 926ms/step - loss: 2.7036
# Epoch 34/200
# 50/50 [==============================] - 46s 910ms/step - loss: 2.6779
# Epoch 35/200
# 50/50 [==============================] - 45s 907ms/step - loss: 2.6084
# Epoch 36/200
# 50/50 [==============================] - 47s 931ms/step - loss: 2.5878
# Epoch 37/200
# 50/50 [==============================] - 32s 637ms/step - loss: 2.5979
# Epoch 38/200
# 50/50 [==============================] - 32s 642ms/step - loss: 2.6335
# Epoch 39/200
# 50/50 [==============================] - 47s 935ms/step - loss: 2.5573
# Epoch 40/200
# 50/50 [==============================] - 46s 918ms/step - loss: 2.5568
# Epoch 41/200
# 50/50 [==============================] - 47s 932ms/step - loss: 2.4811
# Epoch 42/200
# 50/50 [==============================] - 32s 643ms/step - loss: 2.5049
# Epoch 43/200
# 50/50 [==============================] - 46s 922ms/step - loss: 2.4599
# Epoch 44/200
# 50/50 [==============================] - 46s 925ms/step - loss: 2.4531
# Epoch 45/200
# 50/50 [==============================] - 46s 924ms/step - loss: 2.3796
# Epoch 46/200
# 50/50 [==============================] - 46s 918ms/step - loss: 2.3758
# Epoch 47/200
# 50/50 [==============================] - 46s 913ms/step - loss: 2.3489
# Epoch 48/200
# 50/50 [==============================] - 46s 923ms/step - loss: 2.3371
# Epoch 49/200
# 50/50 [==============================] - 46s 922ms/step - loss: 2.3170
# Epoch 50/200
# 50/50 [==============================] - 46s 915ms/step - loss: 2.3133
# Epoch 51/200
# 50/50 [==============================] - 46s 924ms/step - loss: 2.2348
# Epoch 52/200
# 50/50 [==============================] - 46s 922ms/step - loss: 2.2207
# Epoch 53/200
# 50/50 [==============================] - 32s 630ms/step - loss: 2.2560
# Epoch 54/200
# 50/50 [==============================] - 46s 928ms/step - loss: 2.1882
# Epoch 55/200
# 50/50 [==============================] - 46s 922ms/step - loss: 2.1839
# Epoch 56/200
# 50/50 [==============================] - 46s 910ms/step - loss: 2.1050
# Epoch 57/200
# 50/50 [==============================] - 32s 632ms/step - loss: 2.1332
# Epoch 58/200
# 50/50 [==============================] - 32s 643ms/step - loss: 2.1236
# Epoch 59/200
# 50/50 [==============================] - 46s 927ms/step - loss: 2.0811
# Epoch 60/200
# 50/50 [==============================] - 32s 639ms/step - loss: 2.0952
# Epoch 61/200
# 50/50 [==============================] - 47s 935ms/step - loss: 2.0468
# Epoch 62/200
# 50/50 [==============================] - 32s 639ms/step - loss: 2.0649
# Epoch 63/200
# 50/50 [==============================] - 33s 650ms/step - loss: 2.0498
# Epoch 64/200
# 50/50 [==============================] - 33s 658ms/step - loss: 2.0501
# Epoch 65/200
# 50/50 [==============================] - 47s 945ms/step - loss: 2.0358
# Epoch 66/200
# 50/50 [==============================] - 47s 931ms/step - loss: 1.9784
# Epoch 67/200
# 50/50 [==============================] - 46s 926ms/step - loss: 1.9570
# Epoch 68/200
# 50/50 [==============================] - 46s 928ms/step - loss: 1.9169
# Epoch 69/200
# 50/50 [==============================] - 32s 639ms/step - loss: 1.9300
# Epoch 70/200
# 50/50 [==============================] - 47s 942ms/step - loss: 1.8929
# Epoch 71/200
# 50/50 [==============================] - 32s 644ms/step - loss: 1.8937
# Epoch 72/200
# 50/50 [==============================] - 47s 939ms/step - loss: 1.8907
# Epoch 73/200
# 50/50 [==============================] - 46s 924ms/step - loss: 1.8713
# Epoch 74/200
# 50/50 [==============================] - 46s 926ms/step - loss: 1.8298
# Epoch 75/200
# 50/50 [==============================] - 46s 929ms/step - loss: 1.8271
# Epoch 76/200
# 50/50 [==============================] - 46s 922ms/step - loss: 1.7856
# Epoch 77/200
# 50/50 [==============================] - 32s 638ms/step - loss: 1.7909
# Epoch 78/200
# 50/50 [==============================] - 47s 938ms/step - loss: 1.7847
# Epoch 79/200
# 50/50 [==============================] - 47s 930ms/step - loss: 1.7580
# Epoch 80/200
# 50/50 [==============================] - 46s 923ms/step - loss: 1.7372
# Epoch 81/200
# 50/50 [==============================] - 32s 637ms/step - loss: 1.7525
# Epoch 82/200
# 50/50 [==============================] - 46s 929ms/step - loss: 1.7317
# Epoch 83/200
# 50/50 [==============================] - 32s 644ms/step - loss: 1.7325
# Epoch 84/200
# 50/50 [==============================] - 47s 931ms/step - loss: 1.7028
# Epoch 85/200
# 50/50 [==============================] - 47s 933ms/step - loss: 1.6895
# Epoch 86/200
# 50/50 [==============================] - 47s 932ms/step - loss: 1.6754
# Epoch 87/200
# 50/50 [==============================] - 32s 637ms/step - loss: 1.6947
# Epoch 88/200
# 50/50 [==============================] - 33s 650ms/step - loss: 1.6793
# Epoch 89/200
# 50/50 [==============================] - 47s 936ms/step - loss: 1.6715
# Epoch 90/200
# 50/50 [==============================] - 47s 931ms/step - loss: 1.6487
# Epoch 91/200
# 50/50 [==============================] - 46s 926ms/step - loss: 1.6029
# Epoch 92/200
# 50/50 [==============================] - 32s 642ms/step - loss: 1.6171
# Epoch 93/200
# 50/50 [==============================] - 46s 915ms/step - loss: 1.5811
# Epoch 94/200
# 50/50 [==============================] - 32s 646ms/step - loss: 1.6182
# Epoch 95/200
# 50/50 [==============================] - 33s 655ms/step - loss: 1.5882
# Epoch 96/200
# 50/50 [==============================] - 47s 948ms/step - loss: 1.5435
# Epoch 97/200
# 50/50 [==============================] - 47s 931ms/step - loss: 1.5213
# Epoch 98/200
# 50/50 [==============================] - 32s 642ms/step - loss: 1.5340
# Epoch 99/200
# 50/50 [==============================] - 46s 929ms/step - loss: 1.4973
# Epoch 100/200
# 50/50 [==============================] - 32s 645ms/step - loss: 1.5621
# Epoch 101/200
# 50/50 [==============================] - 33s 655ms/step - loss: 1.5398
# Epoch 102/200
# 50/50 [==============================] - 33s 661ms/step - loss: 1.5040
# Epoch 103/200
# 50/50 [==============================] - 48s 954ms/step - loss: 1.4724
# Epoch 104/200
# 50/50 [==============================] - 32s 650ms/step - loss: 1.5228
# Epoch 105/200
# 50/50 [==============================] - 33s 660ms/step - loss: 1.4984
# Epoch 106/200
# 50/50 [==============================] - 33s 669ms/step - loss: 1.4742
# Epoch 107/200
# 50/50 [==============================] - 47s 948ms/step - loss: 1.4496
# Epoch 108/200
# 50/50 [==============================] - 33s 656ms/step - loss: 1.4541
# Epoch 109/200
# 50/50 [==============================] - 48s 959ms/step - loss: 1.4315
# Epoch 110/200
# 50/50 [==============================] - 46s 924ms/step - loss: 1.4144
# Epoch 111/200
# 50/50 [==============================] - 32s 649ms/step - loss: 1.4156
# Epoch 112/200
# 50/50 [==============================] - 47s 935ms/step - loss: 1.3986
# Epoch 113/200
# 50/50 [==============================] - 47s 934ms/step - loss: 1.3824
# Epoch 114/200
# 50/50 [==============================] - 32s 643ms/step - loss: 1.3917
# Epoch 115/200
# 50/50 [==============================] - 33s 653ms/step - loss: 1.4204
# Epoch 116/200
# 50/50 [==============================] - 33s 661ms/step - loss: 1.4487
# Epoch 117/200
# 50/50 [==============================] - 47s 935ms/step - loss: 1.3802
# Epoch 118/200
# 50/50 [==============================] - 46s 915ms/step - loss: 1.3508
# Epoch 119/200
# 50/50 [==============================] - 32s 644ms/step - loss: 1.3747
# Epoch 120/200
# 50/50 [==============================] - 33s 655ms/step - loss: 1.3798
# Epoch 121/200
# 50/50 [==============================] - 47s 949ms/step - loss: 1.3393
# Epoch 122/200
# 50/50 [==============================] - 47s 941ms/step - loss: 1.3131
# Epoch 123/200
# 50/50 [==============================] - 32s 643ms/step - loss: 1.3631
# Epoch 124/200
# 50/50 [==============================] - 33s 653ms/step - loss: 1.3921
# Epoch 125/200
# 50/50 [==============================] - 33s 657ms/step - loss: 1.3798
# Epoch 126/200
# 50/50 [==============================] - 33s 665ms/step - loss: 1.3432
# Epoch 127/200
# 50/50 [==============================] - 33s 666ms/step - loss: 1.3349
# Epoch 128/200
# 50/50 [==============================] - 47s 931ms/step - loss: 1.2983
# Epoch 129/200
# 50/50 [==============================] - 33s 656ms/step - loss: 1.3054
# Epoch 130/200
# 50/50 [==============================] - 33s 664ms/step - loss: 1.2983
# Epoch 131/200
# 50/50 [==============================] - 47s 941ms/step - loss: 1.2849
# Epoch 132/200
# 50/50 [==============================] - 46s 926ms/step - loss: 1.2718
# Epoch 133/200
# 50/50 [==============================] - 32s 645ms/step - loss: 1.2846
# Epoch 134/200
# 50/50 [==============================] - 33s 654ms/step - loss: 1.3345
# Epoch 135/200
# 50/50 [==============================] - 33s 654ms/step - loss: 1.4563
# Epoch 136/200
# 50/50 [==============================] - 33s 656ms/step - loss: 1.3329
# Epoch 137/200
# 50/50 [==============================] - 33s 656ms/step - loss: 1.2748
# Epoch 138/200
# 50/50 [==============================] - 33s 654ms/step - loss: 1.2726
# Epoch 139/200
# 50/50 [==============================] - 47s 941ms/step - loss: 1.2250
# Epoch 140/200
# 50/50 [==============================] - 46s 913ms/step - loss: 1.2229
# Epoch 141/200
# 50/50 [==============================] - 32s 637ms/step - loss: 1.2298
# Epoch 142/200
# 50/50 [==============================] - 32s 646ms/step - loss: 1.2318
# Epoch 143/200
# 50/50 [==============================] - 33s 652ms/step - loss: 1.2348
# Epoch 144/200
# 50/50 [==============================] - 47s 934ms/step - loss: 1.1989
# Epoch 145/200
# 50/50 [==============================] - 32s 642ms/step - loss: 1.1993
# Epoch 146/200
# 50/50 [==============================] - 46s 913ms/step - loss: 1.1916
# Epoch 147/200
# 50/50 [==============================] - 46s 919ms/step - loss: 1.1702
# Epoch 148/200
# 50/50 [==============================] - 32s 636ms/step - loss: 1.1703
# Epoch 149/200
# 50/50 [==============================] - 46s 918ms/step - loss: 1.1514
# Epoch 150/200
# 50/50 [==============================] - 32s 636ms/step - loss: 1.1674
# Epoch 151/200
# 50/50 [==============================] - 45s 903ms/step - loss: 1.1246
# Epoch 152/200
# 50/50 [==============================] - 32s 636ms/step - loss: 1.1278
# Epoch 153/200
# 50/50 [==============================] - 47s 932ms/step - loss: 1.1202
# Epoch 154/200
# 50/50 [==============================] - 46s 921ms/step - loss: 1.1071
# Epoch 155/200
# 50/50 [==============================] - 45s 894ms/step - loss: 1.1047
# Epoch 156/200
# 50/50 [==============================] - 45s 909ms/step - loss: 1.1017
# Epoch 157/200
# 50/50 [==============================] - 45s 907ms/step - loss: 1.0709
# Epoch 158/200
# 50/50 [==============================] - 32s 633ms/step - loss: 1.1069
# Epoch 159/200
# 50/50 [==============================] - 32s 636ms/step - loss: 1.0973
# Epoch 160/200
# 50/50 [==============================] - 32s 643ms/step - loss: 1.0781
# Epoch 161/200
# 50/50 [==============================] - 46s 920ms/step - loss: 1.0619
# Epoch 162/200
# 50/50 [==============================] - 32s 639ms/step - loss: 1.1973
# Epoch 163/200
# 50/50 [==============================] - 32s 646ms/step - loss: 1.1530
# Epoch 164/200
# 50/50 [==============================] - 33s 652ms/step - loss: 1.0738
# Epoch 165/200
# 50/50 [==============================] - 47s 933ms/step - loss: 1.0530
# Epoch 166/200
# 50/50 [==============================] - 46s 928ms/step - loss: 1.0421
# Epoch 167/200
# 50/50 [==============================] - 32s 634ms/step - loss: 1.0445
# Epoch 168/200
# 50/50 [==============================] - 45s 905ms/step - loss: 1.0382
# Epoch 169/200
# 50/50 [==============================] - 45s 893ms/step - loss: 0.9991
# Epoch 170/200
# 50/50 [==============================] - 32s 630ms/step - loss: 1.0209
# Epoch 171/200
# 50/50 [==============================] - 46s 919ms/step - loss: 0.9981
# Epoch 172/200
# 50/50 [==============================] - 32s 635ms/step - loss: 1.0120
# Epoch 173/200
# 50/50 [==============================] - 32s 641ms/step - loss: 1.0358
# Epoch 174/200
# 50/50 [==============================] - 32s 648ms/step - loss: 1.0108
# Epoch 175/200
# 50/50 [==============================] - 46s 918ms/step - loss: 0.9775
# Epoch 176/200
# 50/50 [==============================] - 46s 913ms/step - loss: 0.9663
# Epoch 177/200
# 50/50 [==============================] - 32s 634ms/step - loss: 0.9701
# Epoch 178/200
# 50/50 [==============================] - 46s 924ms/step - loss: 0.9649
# Epoch 179/200
# 50/50 [==============================] - 45s 905ms/step - loss: 0.9568
# Epoch 180/200
# 50/50 [==============================] - 31s 627ms/step - loss: 0.9880
# Epoch 181/200
# 50/50 [==============================] - 32s 635ms/step - loss: 0.9614
# Epoch 182/200
# 50/50 [==============================] - 45s 904ms/step - loss: 0.9403
# Epoch 183/200
# 50/50 [==============================] - 32s 631ms/step - loss: 0.9457
# Epoch 184/200
# 50/50 [==============================] - 45s 896ms/step - loss: 0.9261
# Epoch 185/200
# 50/50 [==============================] - 32s 638ms/step - loss: 0.9323
# Epoch 186/200
# 50/50 [==============================] - 46s 924ms/step - loss: 0.9244
# Epoch 187/200
# 50/50 [==============================] - 44s 888ms/step - loss: 0.8925
# Epoch 188/200
# 50/50 [==============================] - 32s 633ms/step - loss: 0.9016
# Epoch 189/200
# 50/50 [==============================] - 32s 641ms/step - loss: 0.9175
# Epoch 190/200
# 50/50 [==============================] - 32s 645ms/step - loss: 0.9122
# Epoch 191/200
# 50/50 [==============================] - 32s 648ms/step - loss: 0.9508
# Epoch 192/200
# 50/50 [==============================] - 33s 653ms/step - loss: 1.0265
# Epoch 193/200
# 50/50 [==============================] - 33s 651ms/step - loss: 0.9248
# Epoch 194/200
# 50/50 [==============================] - 45s 906ms/step - loss: 0.8846
# Epoch 195/200
# 50/50 [==============================] - 45s 900ms/step - loss: 0.8770
# Epoch 196/200
# 50/50 [==============================] - 45s 900ms/step - loss: 0.8688
# Epoch 197/200
# 50/50 [==============================] - 32s 631ms/step - loss: 0.9103
# Epoch 198/200
# 50/50 [==============================] - 32s 640ms/step - loss: 0.9088
# Epoch 199/200
# 50/50 [==============================] - 32s 647ms/step - loss: 0.8952
# Epoch 200/200
# 50/50 [==============================] - 46s 919ms/step - loss: 0.8584

# %%
tf.train.latest_checkpoint(checkpoint_dir)
# Out:
# '/content/gdrive/My Drive/training_checkpoints/complex/weights.200-0.86'

# %%
model = build_model(vocab_size, embedding_dim, rnn_units, batch_size=1)

model.load_weights('/content/gdrive/My Drive/training_checkpoints/complex/weights.200-0.86')#tf.train.latest_checkpoint(checkpoint_dir))

model.build(tf.TensorShape([1, None]))
# Out:
# 18

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (1, None, 500)            912000
# _________________________________________________________________
# cu_dnngru_3 (CuDNNGRU)       (1, None, 3072)           32937984
# _________________________________________________________________
# cu_dnngru_4 (CuDNNGRU)       (1, None, 3072)           56641536
# _________________________________________________________________
# cu_dnngru_5 (CuDNNGRU)       (1, None, 3072)           56641536
# _________________________________________________________________
# dense_1 (Dense)              (1, None, 1824)           5605152
# =================================================================
# Total params: 152,738,208
# Trainable params: 152,738,208
# Non-trainable params: 0
# _________________________________________________________________

# %%
def find_word(idx):
  return list(tokenizer.word_index.keys())[list(tokenizer.word_index.values()).index(idx)]

def generate_text(model, start_string):
    # Evaluation step (generating text using the learned model)

    # Number of characters to generate
    num_generate = 10

    # Converting our start string to numbers (vectorizing) 
    input_eval = [tokenizer.word_index[s] for s in start_string.split()]
#     input_eval = tf.expand_dims(input_eval, 0)
    input_eval = tf.expand_dims(input_eval, 0)

    # Empty string to store our results
    text_generated = []

    # Low temperatures results in more predictable text.
    # Higher temperatures results ifst tsnn more surprising text.
    # Experiment to find the best setting.
    temperature = 2
   

    # Here batch size == 1
    model.reset_states()
    for i in range(num_generate):
        predictions = model(input_eval)

        # using a multinomial distribution to predict the word returned by the model
        predictions = predictions / temperature
        predicted_id = tf.multinomial(logits=predictions[0], num_samples=1)[-1,0].numpy()


        # We pass the predicted word as the next input to the model
        # along with the previous hidden state
        input_eval = tf.expand_dims([predicted_id+1], 0)

        text_generated.append(find_word(predicted_id+1))

    return (start_string + ' ' + ' '.join(text_generated))

# %%
for i in range(10):
  print(generate_text(model, start_string=u"josh hamilton"))
# Out:
# josh hamilton supervis far go late make longestlistofnighttimewinnersinnohtexa op born cocain allstar
# josh hamilton late best otd anaheim best gl late go wear embarrassingli
# josh hamilton among star longestlistofnighttimewinnersinnohtexa 31 otd paid tog pitch late even
# josh hamilton unfoun game pitch continu realli bobbi 5 late make pitch
# josh hamilton safe home lot basketbal basebal loss pitch make terribl r
# josh hamilton nice far houston offenc much woodi allstar bas youth royal
# josh hamilton among anaheim ray exclus super park understand height definit lead
# josh hamilton among entir best level pitch akin night someth bet take
# josh hamilton among best aug late make best even home yr pitch
# josh hamilton helen two see pla touch want houston who competit allstar

# %%
# %ls
# Out:
# gdrive/  sample_data/

# %%
# %cd gdrive/My\ Drive/training_checkpoints/complex
# Out:
# /content/gdrive/My Drive/training_checkpoints/complex

# %%
# %ls
# Out:
# checkpoint                            weights.27-4.53.data-00001-of-00002
# weights.01-10.20.data-00000-of-00002  weights.27-4.53.index
# weights.01-10.20.data-00001-of-00002  weights.32-4.52.data-00000-of-00002
# weights.01-10.20.index                weights.32-4.52.data-00001-of-00002
# weights.02-5.18.data-00000-of-00002   weights.32-4.52.index
# weights.02-5.18.data-00001-of-00002   weights.34-4.51.data-00000-of-00002
# weights.02-5.18.index                 weights.34-4.51.data-00001-of-00002
# weights.03-5.07.data-00000-of-00002   weights.34-4.51.index
# weights.03-5.07.data-00001-of-00002   weights.35-4.50.data-00000-of-00002
# weights.03-5.07.index                 weights.35-4.50.data-00001-of-00002
# weights.04-5.02.data-00000-of-00002   weights.35-4.50.index
# weights.04-5.02.data-00001-of-00002   weights.36-4.49.data-00000-of-00002
# weights.04-5.02.index                 weights.36-4.49.data-00001-of-00002
# weights.05-4.96.data-00000-of-00002   weights.36-4.49.index
# weights.05-4.96.data-00001-of-00002   weights.40-4.47.data-00000-of-00002
# weights.05-4.96.index                 weights.40-4.47.data-00001-of-00002
# weights.06-4.94.data-00000-of-00002   weights.40-4.47.index
# weights.06-4.94.data-00001-of-00002   weights.43-4.47.data-00000-of-00002
# weights.06-4.94.index                 weights.43-4.47.data-00001-of-00002
# weights.07-4.88.data-00000-of-00002   weights.43-4.47.index
# weights.07-4.88.data-00001-of-00002   weights.46-4.44.data-00000-of-00002
# weights.07-4.88.index                 weights.46-4.44.data-00001-of-00002
# weights.08-4.85.data-00000-of-00002   weights.46-4.44.index
# weights.08-4.85.data-00001-of-00002   weights.48-4.42.data-00000-of-00002
# weights.08-4.85.index                 weights.48-4.42.data-00001-of-00002
# weights.09-4.80.data-00000-of-00002   weights.48-4.42.index
# weights.09-4.80.data-00001-of-00002   weights.50-4.41.data-00000-of-00002
# weights.09-4.80.index                 weights.50-4.41.data-00001-of-00002
# weights.10-4.79.data-00000-of-00002   weights.50-4.41.index
# weights.10-4.79.data-00001-of-00002   weights.52-4.38.data-00000-of-00002
# weights.10-4.79.index                 weights.52-4.38.data-00001-of-00002
# weights.12-4.76.data-00000-of-00002   weights.52-4.38.index
# weights.12-4.76.data-00001-of-00002   weights.67-4.36.data-00000-of-00002
# weights.12-4.76.index                 weights.67-4.36.data-00001-of-00002
# weights.13-4.75.data-00000-of-00002   weights.67-4.36.index
# weights.13-4.75.data-00001-of-00002   weights.68-4.35.data-00000-of-00002
# weights.13-4.75.index                 weights.68-4.35.data-00001-of-00002
# weights.14-4.73.data-00000-of-00002   weights.68-4.35.index
# weights.14-4.73.data-00001-of-00002   weights.73-4.35.data-00000-of-00002
# weights.14-4.73.index                 weights.73-4.35.data-00001-of-00002
# weights.15-4.70.data-00000-of-00002   weights.73-4.35.index
# weights.15-4.70.data-00001-of-00002   weights.75-4.34.data-00000-of-00002
# weights.15-4.70.index                 weights.75-4.34.data-00001-of-00002
# weights.16-4.66.data-00000-of-00002   weights.75-4.34.index
# weights.16-4.66.data-00001-of-00002   weights.76-4.32.data-00000-of-00002
# weights.16-4.66.index                 weights.76-4.32.data-00001-of-00002
# weights.19-4.64.data-00000-of-00002   weights.76-4.32.index
# weights.19-4.64.data-00001-of-00002   weights.79-4.31.data-00000-of-00002
# weights.19-4.64.index                 weights.79-4.31.data-00001-of-00002
# weights.20-4.62.data-00000-of-00002   weights.79-4.31.index
# weights.20-4.62.data-00001-of-00002   weights.85-4.31.data-00000-of-00002
# weights.20-4.62.index                 weights.85-4.31.data-00001-of-00002
# weights.22-4.59.data-00000-of-00002   weights.85-4.31.index
# weights.22-4.59.data-00001-of-00002   weights.88-4.29.data-00000-of-00002
# weights.22-4.59.index                 weights.88-4.29.data-00001-of-00002
# weights.23-4.58.data-00000-of-00002   weights.88-4.29.index
# weights.23-4.58.data-00001-of-00002   weights.96-4.27.data-00000-of-00002
# weights.23-4.58.index                 weights.96-4.27.data-00001-of-00002
# weights.25-4.55.data-00000-of-00002   weights.96-4.27.index
# weights.25-4.55.data-00001-of-00002   weights.98-4.25.data-00000-of-00002
# weights.25-4.55.index                 weights.98-4.25.data-00001-of-00002
# weights.27-4.53.data-00000-of-00002   weights.98-4.25.index

# %%
# %rm -rf *
