# %%
from __future__ import absolute_import, division, print_function

import tensorflow as tf
tf.enable_eager_execution()

import numpy as np
import os
import time
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Read, then decode for py2 compat.
text = open('/content/gdrive/My Drive/for_tensorflow.csv', 'rb').read().decode(encoding='utf-8')
# length of text is the number of characters in it
print ('Length of text: {} characters'.format(len(text)))
# Out:
# Length of text: 32938 characters

# %%
# Take a look at the first 250 characters in text
print(text[:250])
# Out:
# clean
# rais hand question jr ranger club member get exclus q/a hunter satu
# better way kick vacat settl watch win move 2nd wildcard spot
# proud announc today multi-year panership globe life field offici exclus
# live radio thur may 30th today 4pm pt/7pm e

# %%
sorted(set(text.split()))
# Out:
# ["''",
#  '+115',
#  '+148',
#  '1-0',
#  '1/2',
#  '10-0',
#  '10-2',
#  '10-day',
#  '100th',
#  '1020am/1120am/1220pm/120pm/220pm',
#  '1053thefandfw',
#  '10k+',
#  '10th',
#  '11-0',
#  '11-game',
#  '11th',
#  '11u',
#  '12-4',
#  '12th',
#  '14-0',
#  '14-yr',
#  '15-5',
#  '17-0',
#  '17-yr',
#  '18-9',
#  '1st',
#  '2-0',
#  '21st',
#  '24-23',
#  '276/349/449',
#  '28th',
#  '2nd',
#  '3-1',
#  '3-2',
#  '3-5',
#  '30th',
#  '31st',
#  '38th',
#  '3rd',
#  '4-2',
#  '4-run',
#  '4-year-old',
#  '40th',
#  '44-2',
#  '45th',
#  '47k',
#  '4pm',
#  '4th',
#  '5-1',
#  '5-27',
#  '5-30',
#  '5/31',
#  '500kva',
#  '56min',
#  '5th',
#  '5x',
#  '6th',
#  '6xall',
#  '7-1',
#  '7-year',
#  '730pm',
#  '7th',
#  '8th',
#  '9th',
#  '``',
#  'a-rod',
#  'aaron',
#  'ab',
#  'abl',
#  'absolut',
#  'academi',
#  'account',
#  'ace',
#  'across',
#  'act',
#  'acti',
#  'activ',
#  'actual',
#  'ad',
#  'adam',
#  'add',
#  'adjust',
#  'adopt',
#  'adrian',
#  'advantag',
#  'adventuretravel',
#  'advic',
#  'afford',
#  'afternoon',
#  'age',
#  'ago',
#  'agre',
#  'ahead',
#  'aicl',
#  'aid',
#  'air',
#  'aisl',
#  'akin',
#  'al',
#  'alarm',
#  'albeo',
#  'alcohol',
#  'aledmi',
#  'aledo',
#  'all-star',
#  'all-you-can-eat',
#  'alley',
#  'allig',
#  'allow',
#  'allstar',
#  'almost',
#  'alon',
#  'along',
#  'alreadi',
#  'alright',
#  'also',
#  'altuv',
#  'alumnus',
#  'alway',
#  'amaz',
#  'amazon',
#  'american',
#  'among',
#  'amp',
#  'anaheim',
#  'analyt',
#  'andrew',
#  'andru',
#  'ang',
#  'angel',
#  'angelsastro',
#  'angl',
#  'anniversari',
#  'announc',
#  'annual',
#  'anoth',
#  'answer',
#  'anthem',
#  'anybodi',
#  'anyth',
#  'anyway',
#  'app',
#  'appar',
#  'appear',
#  'appearanc',
#  'appletv',
#  'applic',
#  'appro',
#  'approach',
#  'apr',
#  'area',
#  'ariel',
#  'arizona',
#  'arlingto',
#  'arlington',
#  'arm',
#  'armi',
#  'arod',
#  'around',
#  'as',
#  'asdrub',
#  'asg',
#  'asham',
#  'assign',
#  'astro',
#  'athlet',
#  'attend',
#  'attent',
#  'attn',
#  'attract',
#  'aug',
#  'austin',
#  'auto',
#  'averag',
#  'averil',
#  'avg',
#  'away',
#  'awesom',
#  'b',
#  'ba',
#  'back',
#  'back-to-back',
#  'bad',
#  'bag',
#  'baitulma',
#  'ball',
#  'ballgamewith',
#  'ballot',
#  'ballpark',
#  'base',
#  'basebal',
#  'baseman',
#  'basketbal',
#  'bat',
#  'batter',
#  'battl',
#  'bc',
#  'beach',
#  'beard',
#  'beat',
#  'bed',
#  'befor',
#  'begin',
#  'behind',
#  'bel',
#  'believ',
#  'belling',
#  'belong',
#  'belpr',
#  'beltr',
#  'beltran',
#  'benefit',
#  'berroa',
#  'best',
#  'bet',
#  'better',
#  'beyond',
#  'bff',
#  'bi',
#  'big',
#  'bigger',
#  'bihday',
#  'bill',
#  'binge-watch',
#  'bio',
#  'bird',
#  'bishop',
#  'bit',
#  'blacki',
#  'blame',
#  'blast',
#  'blatantli',
#  'bleacheweet',
#  'bless',
#  'blew',
#  'block',
#  'blog',
#  'blow',
#  'blue',
#  'bluebonnet',
#  'bo',
#  'board',
#  'bob',
#  'bobbi',
#  'bobbl',
#  'bobblehead',
#  'bodi',
#  'bomb',
#  'booth',
#  'bor',
#  'born',
#  'bos',
#  'bother',
#  'bottom',
#  'bought',
#  'bout',
#  'box',
#  'boy',
#  'boyd',
#  'bozo',
#  'bradfield',
#  'brandon',
#  'breakthrough',
#  'brief',
#  'brilliantli',
#  'bring',
#  'broadcast',
#  'brought',
#  'bu',
#  'buckn',
#  'buddi',
#  'buechel',
#  'build',
#  'bull',
#  'bullpen',
#  'bullpenfailur',
#  'bullshit',
#  'bummer',
#  'bunch',
#  'busi',
#  'bust',
#  'buster',
#  'butcher',
#  'butt',
#  'buy',
#  'c',
#  'ca',
#  'cabbi',
#  'cabrera',
#  'cade',
#  'calhoun',
#  'california',
#  'call',
#  'came',
#  'camp',
#  'canada',
#  'cancer',
#  'cant',
#  'cap',
#  'car',
#  'card',
#  'care',
#  'career',
#  'carlo',
#  'carri',
#  'casino',
#  'cat',
#  'catch',
#  'catcher',
#  'categori',
#  'caw',
#  'celebr',
#  'center',
#  'ceremoni',
#  'cf',
#  'cg',
#  'cha',
#  'challeng',
#  'champion',
#  'championship',
#  'chanc',
#  'chang',
#  'chant',
#  'charact',
#  'charg',
#  'charliehough',
#  'chavez',
#  'check',
#  'cheer',
#  'chick-fil-a',
#  'choctaw',
#  'choic',
#  'cholo',
#  'choo',
#  'choos',
#  'chri',
#  'christi',
#  'cinci',
#  'circu',
#  'cit',
#  'citi',
#  'class',
#  'clean',
#  'close',
#  'closer',
#  'closet',
#  'cloth',
#  'cloudi',
#  'club',
#  'coach',
#  'coast',
#  'cocain',
#  'code',
#  'coez',
#  'coincid',
#  'colbi',
#  'cold',
#  'colleg',
#  'column',
#  'columnist',
#  'combin',
#  'combo',
#  'come',
#  'comeback',
#  'comeptit',
#  'comer',
#  'cominglim-er',
#  'commend',
#  'compar',
#  'competit',
#  'compil',
#  'complain',
#  'complet',
#  'conc',
#  'conclus',
#  'confid',
#  'confirm',
#  'congrat',
#  'congratul',
#  'conscienc',
#  'consecut',
#  'contact',
#  'contend',
#  'continu',
#  'convinc',
#  'cool',
#  'correctli',
#  'couesi',
#  'could',
#  'couldnt',
#  'count',
#  'countri',
#  'coupl',
#  'cours',
#  'cover',
#  'coverag',
#  'cowboy',
#  'cowlishaw',
#  'cr',
#  'crawford',
#  'creat',
#  'critic',
#  'crook',
#  'crowd',
#  'crush',
#  'crystal',
#  'ct',
#  'cub',
#  'cunningham',
#  'cup',
#  'custom',
#  'cut',
#  'cuz',
#  'dad',
#  'daddi',
#  'daili',
#  'dalla',
#  'damn',
#  'danger',
#  'daniel',
#  'danni',
#  'darwin',
#  'date',
#  'daughter',
#  'dave',
#  'david',
#  'day',
#  'daytim',
#  'dc',
#  'de',
#  'deal',
#  'dear',
#  'debut',
#  'decent',
#  'decid',
#  'decis',
#  'deep',
#  'defendin',
#  'defens',
#  'definit',
#  'degre',
#  'delay',
#  'delino',
#  'deliv',
#  'denial',
#  'depament',
#  'depend',
#  'derbi',
#  'derek',
#  'deserv',
#  'deshield',
#  'desi',
#  'design',
#  'desk',
#  'despit',
#  'detlef',
#  'detroit',
#  'devon',
#  'dfw',
#  'didnt',
#  'die',
#  'differ',
#  'digit',
#  'dillard',
#  'dinger',
#  'disappoint',
#  'discount',
#  'discus',
#  'dish',
#  'disney',
#  'district',
#  'divis',
#  'dm',
#  'doc',
#  'docker',
#  'doesnt',
#  'dog',
#  'dollar',
#  'domin',
#  'done',
#  'donor-fund',
#  'dont',
#  'doubl',
#  'dowdi',
#  'downtown',
#  'doze',
#  'draft',
#  'draftk',
#  'dream',
#  'drew',
#  'drive',
#  'drivin',
#  'drop',
#  'drove',
#  'dude',
#  'dumb',
#  'dynam',
#  'e',
#  'earl',
#  'earli',
#  'earlier',
#  'earn',
#  'easi',
#  'eat',
#  'edg',
#  'edit',
#  'edited/produc',
#  'editor',
#  'effici',
#  'egregi',
#  'eight',
#  'either',
#  'elvi',
#  'email',
#  'embarrass',
#  'embarrassingli',
#  'emot',
#  'empti',
#  'en',
#  'encor',
#  'end',
#  'english',
#  'enjoy',
#  'enough',
#  'enrout',
#  'ensembl',
#  'enteain',
#  'enter',
#  'entir',
#  'entri',
#  'episod',
#  'equal',
#  'era',
#  'eric',
#  'error',
#  'especi',
#  'et',
#  'ev',
#  'even',
#  'ever',
#  'everi',
#  'everybodi',
#  'everyon',
#  'everyth',
#  'everythin',
#  'ex',
#  'exam',
#  'excel',
#  'except',
#  'excit',
#  'excitedli',
#  'exclus',
#  'excus',
#  'exist',
#  'exit',
#  'exp',
#  'expect',
#  'experi',
#  'explain',
#  'extend',
#  'extra',
#  'eye',
#  'f',
#  'fa',
#  'face',
#  'fact',
#  'fairfi',
#  'fake',
#  'fall',
#  'fals',
#  'fame',
#  'famer',
#  'famili',
#  'fan',
#  'fanci',
#  'far',
#  'fashion',
#  'faso',
#  'fast',
#  'fastbal',
#  'father',
#  'fave',
#  'favorit',
#  'fearlessli',
#  'featur',
#  'feel',
#  'fellow',
#  'felt',
#  'fewer',
#  'field',
#  'fielder',
#  'fifth',
#  'fight',
#  'figu',
#  'figur',
#  'fill',
#  'fin',
#  'final',
#  'find',
#  'finish',
#  'fire',
#  'firework',
#  'first',
#  'five',
#  'fl',
#  'flash',
#  'flashbackfriday',
#  'floati',
#  'flythew',
#  'fo',
#  'folk',
#  'follow',
#  'food',
#  'fool',
#  'foot',
#  'footbal',
#  'forc',
#  'forget',
#  'forgot',
#  'forgotten',
#  'format',
#  'former',
#  'forsyth',
#  'foul',
#  'foun',
#  'foundat',
#  'four',
#  'four-ga',
#  'fox',
#  'fra',
#  'fraley',
#  'franchis',
#  'free',
#  'freedom',
#  'friday',
#  'friend',
#  'frog',
#  'front',
#  'frown',
#  'ft/f',
#  'fuck',
#  'full',
#  'fulltimerv',
#  'fun',
#  'funni',
#  'futur',
#  'g',
#  'ga',
#  'gagnon',
#  'gallo',
#  'gallop',
#  'game',
#  'gameofthron',
#  'ganna',
#  'garbag',
#  'gari',
#  'gateke',
#  'gatekeep',
#  'gator',
#  'gave',
#  'gem',
#  'geographi',
#  'georg',
#  'germani',
#  'geronimo',
#  'gerri',
#  'get',
#  'gi',
#  'gif',
#  'gift',
#  'girl',
#  'gisd',
#  'give',
#  'giveawa',
#  'giveaway',
#  'given',
#  'gl',
#  'glad',
#  'gladli',
#  'glenn',
#  'gleyber',
#  'glf',
#  'globe',
#  'glp',
#  'gm',
#  'go',
#  'goal',
#  'goddamn',
#  'goe',
#  'goi',
#  'goingwithamarinersfan',
#  'gold',
#  'golfer',
#  'gomez',
#  'gon',
#  'gone',
#  'good',
#  'goodgiv',
#  'googl',
#  'gorang',
#  'gorgeousand',
#  'got',
#  'gotcha',
#  'gotten',
#  'grab',
#  'grace',
#  'graduat',
#  'grand',
#  'grandma',
#  'grandmoth',
#  'grandson',
#  'grate',
#  'great',
#  'greatest',
#  'green',
#  'green-them',
#  'greenvil',
#  'greet',
#  'griev',
#  'grit',
#  'groov',
#  'groun',
#  'grounder',
#  'group',
#  'grow',
#  'grown',
#  'grumpi',
#  'guess',
#  'guy',
#  'guyer',
#  'guzzi',
#  'h',
#  'habit',
#  'half',
#  'hall',
#  'hambon',
#  'hamilton',
#  'hand',
#  'handedli',
#  'handl',
#  'happen',
#  'happi',
#  'harang',
#  'hard',
#  'hardin-simmon',
#  'hardli',
#  'harrah',
#  'harrison',
#  'hasnt',
#  'hat',
#  'hate',
#  'havent',
#  'hbo',
#  'he',
#  'hea',
#  'heabroken',
#  'head',
#  'header',
#  'healthi',
#  'heaney',
#  'hear',
#  'heard',
#  'heat',
#  'height',
#  'helen',
#  'hell',
#  'hello',
#  'hellowincolumn',
#  'help',
#  'henk',
#  'here',
#  'hero',
#  'herrera',
#  'hey',
#  'hi',
#  'hick',
#  'hickori',
#  'high',
#  'higher',
#  'highest',
#  'highlight',
#  'hilari',
#  'hint',
#  'hire',
#  'histori',
#  'hit',
#  'hitter',
#  'hof',
#  'hold',
#  'home',
#  'homer',
#  'homestand',
#  'honeycutt',
#  'honor',
#  'hope',
#  'horn',
#  'horribl',
#  'host',
#  'hot',
#  'hotel',
#  'hotst',
#  'hour',
#  'hous',
#  'houston',
#  'hr',
#  'ht',
#  'http',
#  'https/',
#  'https//',
#  'hu',
#  'huff',
#  'huge',
#  'hunter',
#  'hunti',
#  'husband/futur',
#  'hyper',
#  'i',
#  'iceberg',
#  'icymi',
#  'id',
#  'idea',
#  'il',
#  'ill',
#  'im',
#  'imagin',
#  'imma',
#  'immedi',
#  'impact',
#  'improv',
#  'in',
#  'inaugu',
#  'inc',
#  'includ',
#  'incred',
#  'indian',
#  'induct',
#  'injuri',
#  'inning',
#  'insid',
#  'instal',
#  'installmen',
#  'instant',
#  'instead',
#  'instinct',
#  'intellig',
#  'interact',
#  'intercontinent',
#  'interview',
#  'introduc',
#  'invest',
#  'ip',
#  'isd',
#  'island',
#  'isnt',
#  'issu',
#  'itd',
#  'ive',
#  'izzi',
#  'j',
#  'j/',
#  'jacki',
#  'jacksonvil',
#  'jake',
#  'jami',
#  'jay',
#  'jeanmar',
#  'jedi',
#  'jeffi',
#  'jere',
#  'jerri',
#  'jess',
#  'jeter',
#  'jettison',
#  'jihadist',
#  'job',
#  'joey',
#  'john',
#  'join',
#  'joint',
#  'joke',
#  'jon',
#  'jose',
#  'josewatch',
#  'josh',
#  'joshhamilton',
#  'jp',
#  'jr',
#  'ju',
#  'judgment',
#  'juici',
#  'jul',
#  'julio',
#  'jump',
#  'jun',
#  'june',
#  'jurado',
#  'justin',
#  'k',
#  'k/9ip',
#  'kansa',
#  'kc',
#  'ke',
#  'keep',
#  'keller',
#  'kelley',
#  'kelli',
#  'ketchup',
#  'keuchel',
#  'kevin',
#  'kick',
#  'kid',
#  'kiddo',
#  'kil',
#  'kind',
#  'kinda',
#  'know',
#  'knuck',
#  'knucklebal',
#  'koe',
#  'korean',
#  'krush',
#  'kxt',
#  'kyle',
#  'l',
#  'la',
#  'laa',
#  'ladi',
#  'lake',
#  'lanc',
#  'land',
#  'lash',
#  'last',
#  'late',
#  'late-night',
#  'latest',
#  'laugh',
#  'laughabl',
#  'launch',
#  'le',
#  'lead',
#  'leader',
#  'leagu',
#  'learn',
#  'leather',
#  'leav',
#  'leclerc',
#  'led',
#  'left',
#  'lefti',
#  'legendari',
#  'legitim',
#  'let',
#  'level',
#  'lewi',
#  'lhp',
#  'lif',
#  'life',
#  'like',
#  'limit',
#  'line',
#  'linear',
#  'lineup',
#  'link',
#  'list',
#  'listen',
#  'littl',
#  'live',
#  'locat',
#  'lock',
#  'log',
#  'logan',
#  'logi',
#  'logo',
#  'lol',
#  'long',
#  'long-term',
#  'longer',
#  'longestlistofnighttimewinnersinnohtexa',
#  'longi',
#  'look',
#  'lord',
#  'lose',
#  'loser',
#  'loss',
#  'lost',
#  'lot',
#  'loui',
#  'love',
#  'lovin',
#  'low',
#  'luck',
#  'lumber',
#  'lunch',
#  'lynn',
#  'm',
#  'made',
#  'main',
#  'mainez',
#  'majo',
#  'make',
#  ...]

# %%
# The unique characters in the file
vocab = sorted(set(text.split()))
print ('{} unique words'.format(len(vocab)))
# Out:
# 1824 unique words

# %%
# Creating a mapping from unique characters to indices
char2idx = {u:i for i, u in enumerate(vocab)}
idx2char = np.array(vocab)

text_as_int = np.array([char2idx[c] for c in text.split()])

# %%
print('{')
for char,_ in zip(char2idx, range(20)):
    print('  {:4s}: {:3d},'.format(repr(char), char2idx[char]))
print('  ...\n}')
# Out:
# {
#   "''":   0,
#   '+115':   1,
#   '+148':   2,
#   '1-0':   3,
#   '1/2':   4,
#   '10-0':   5,
#   '10-2':   6,
#   '10-day':   7,
#   '100th':   8,
#   '1020am/1120am/1220pm/120pm/220pm':   9,
#   '1053thefandfw':  10,
#   '10k+':  11,
#   '10th':  12,
#   '11-0':  13,
#   '11-game':  14,
#   '11th':  15,
#   '11u':  16,
#   '12-4':  17,
#   '12th':  18,
#   '14-0':  19,
#   ...
# }

# %%
# Show how the first 13 characters from the text are mapped to integers
print ('{} ---- characters mapped to int ---- > {}'.format(repr(text[:13]), text_as_int[:13]))
# Out:
# 'clean\nrais ha' ---- characters mapped to int ---- > [ 342 1268  737 1260  886 1272  348 1024  666  551 1255  812 1366]

# %%
# The maximum length sentence we want for a single input in characters
seq_length = 10
BATCH_SIZE = 64
examples_per_epoch = len(text)//seq_length
steps_per_epoch = examples_per_epoch//BATCH_SIZE

# Create training examples / targets
char_dataset = tf.data.Dataset.from_tensor_slices(text_as_int)

for i in char_dataset.take(5):
  print(idx2char[i.numpy()])
# Out:
# clean
# rais
# hand
# question
# jr

# %%
sequences = char_dataset.batch(seq_length+1, drop_remainder=True)

for item in sequences.take(5):
  print(repr(' '.join(idx2char[item.numpy()])))
# Out:
# 'clean rais hand question jr ranger club member get exclus q/a'
# 'hunter satu better way kick vacat settl watch win move 2nd'
# 'wildcard spot proud announc today multi-year panership globe life field offici'
# 'exclus live radio thur may 30th today 4pm pt/7pm et amp'
# 'talk mlb amp surg septemb retir nolan ryan ballpark arlington first'

# %%
def split_input_target(chunk):
    input_text = chunk[:-1]
    target_text = chunk[1:]
    return input_text, target_text

dataset = sequences.map(split_input_target)

# %%
for input_example, target_example in  dataset.take(1):
    print ('Input data: ', repr(' '.join(idx2char[input_example.numpy()])))
    print ('Target data:', repr(' '.join(idx2char[target_example.numpy()])))
# Out:
# Input data:  'clean rais hand question jr ranger club member get exclus'
# Target data: 'rais hand question jr ranger club member get exclus q/a'

# %%
for i, (input_idx, target_idx) in enumerate(zip(input_example[:5], target_example[:5])):
    print("Step {:4d}".format(i))
    print("  input: {} ({:s})".format(input_idx, repr(idx2char[input_idx])))
    print("  expected output: {} ({:s})".format(target_idx, repr(idx2char[target_idx])))
# Out:
# Step    0
#   input: 342 ('clean')
#   expected output: 1268 ('rais')
# Step    1
#   input: 1268 ('rais')
#   expected output: 737 ('hand')
# Step    2
#   input: 737 ('hand')
#   expected output: 1260 ('question')
# Step    3
#   input: 1260 ('question')
#   expected output: 886 ('jr')
# Step    4
#   input: 886 ('jr')
#   expected output: 1272 ('ranger')

# %%
# Batch size 
BATCH_SIZE = 64
steps_per_epoch = examples_per_epoch//BATCH_SIZE

# Buffer size to shuffle the dataset
# (TF data is designed to work with possibly infinite sequences, 
# so it doesn't attempt to shuffle the entire sequence in memory. Instead, 
# it maintains a buffer in which it shuffles elements).
BUFFER_SIZE = 10000

dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

dataset
# Out:
# <DatasetV1Adapter shapes: ((64, 10), (64, 10)), types: (tf.int64, tf.int64)>

# %%
# Length of the vocabulary in chars
vocab_size = len(vocab)

# The embedding dimension 
embedding_dim = 50

# Number of RNN units
rnn_units = 1024

# %%
if tf.test.is_gpu_available():
    rnn = tf.keras.layers.CuDNNGRU
else:
    import functools
    rnn = functools.partial(
    tf.keras.layers.GRU, recurrent_activation='sigmoid')

# %%
def build_model(vocab_size, embedding_dim, rnn_units, batch_size):
    model = tf.keras.Sequential([
     
    tf.keras.layers.Embedding(vocab_size, embedding_dim, 
                              batch_input_shape=[batch_size, None]),
    rnn(rnn_units,
        return_sequences=True, 
        recurrent_initializer='glorot_uniform',
        stateful=True),
    rnn(rnn_units,
        return_sequences=True, 
        recurrent_initializer='glorot_uniform',
        stateful=True),
    rnn(rnn_units,
        return_sequences=True, 
        recurrent_initializer='glorot_uniform',
        stateful=True),
    tf.keras.layers.Dense(vocab_size)
    ])
    return model

# %%
model = build_model(
  vocab_size = len(vocab), 
  embedding_dim=embedding_dim, 
  rnn_units=rnn_units, 
  batch_size=BATCH_SIZE)

# %%
for input_example_batch, target_example_batch in dataset.take(1): 
    example_batch_predictions = model(input_example_batch)
    print(example_batch_predictions.shape, "# (batch_size, sequence_length, vocab_size)")
# Out:
# (64, 10, 1824) # (batch_size, sequence_length, vocab_size)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (64, None, 50)            91200
# _________________________________________________________________
# gru_9 (GRU)                  (64, None, 1024)          3302400
# _________________________________________________________________
# gru_10 (GRU)                 (64, None, 1024)          6294528
# _________________________________________________________________
# gru_11 (GRU)                 (64, None, 1024)          6294528
# _________________________________________________________________
# dense_3 (Dense)              (64, None, 1824)          1869600
# =================================================================
# Total params: 17,852,256
# Trainable params: 17,852,256
# Non-trainable params: 0
# _________________________________________________________________

# %%
def loss(labels, logits):
  return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

# %%
model.compile(
    optimizer = tf.train.AdamOptimizer(),
    loss = loss)

# %%
# Directory where the checkpoints will be saved
checkpoint_dir = '/content/gdrive/My Drive/training_checkpoints/simple'
# Name of the checkpoint files
checkpoint_prefix = os.path.join(checkpoint_dir, "weights.{epoch:02d}-{loss:.2f}")

checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    monitor='loss',
    save_weights_only=True,
    save_best_only=True)

# %%
EPOCHS=100

# %%
history = model.fit(dataset.repeat(), epochs=EPOCHS, steps_per_epoch=steps_per_epoch, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/100
# 51/51 [==============================] - 241s 5s/step - loss: 7.1809
# Epoch 2/100
# 51/51 [==============================] - 236s 5s/step - loss: 6.5672
# Epoch 3/100
# 51/51 [==============================] - 237s 5s/step - loss: 4.7789
# Epoch 4/100
# 51/51 [==============================] - 237s 5s/step - loss: 2.6289
# Epoch 5/100
# 51/51 [==============================] - 234s 5s/step - loss: 1.5408
# Epoch 6/100
# 51/51 [==============================] - 238s 5s/step - loss: 1.0743
# Epoch 7/100
# 51/51 [==============================] - 236s 5s/step - loss: 0.8274
# Epoch 8/100
# 51/51 [==============================] - 237s 5s/step - loss: 0.6605
# Epoch 9/100
# 51/51 [==============================] - 237s 5s/step - loss: 0.5456
# Epoch 10/100
# 51/51 [==============================] - 234s 5s/step - loss: 0.4506
# Epoch 11/100
# 51/51 [==============================] - 234s 5s/step - loss: 0.3840
# Epoch 12/100
# 51/51 [==============================] - 236s 5s/step - loss: 0.3219
# Epoch 13/100
# 51/51 [==============================] - 235s 5s/step - loss: 0.2784
# Epoch 14/100
# 51/51 [==============================] - 238s 5s/step - loss: 0.2370
# Epoch 15/100
# 51/51 [==============================] - 236s 5s/step - loss: 0.2002
# Epoch 16/100
# 51/51 [==============================] - 237s 5s/step - loss: 0.1830
# Epoch 17/100
# 51/51 [==============================] - 238s 5s/step - loss: 0.1574
# Epoch 18/100
# 51/51 [==============================] - 240s 5s/step - loss: 0.1396
# Epoch 19/100
# 51/51 [==============================] - 242s 5s/step - loss: 0.1294
# Epoch 20/100
# 51/51 [==============================] - 242s 5s/step - loss: 0.1233
# Epoch 21/100
# 51/51 [==============================] - 241s 5s/step - loss: 0.1152
# Epoch 22/100
# 51/51 [==============================] - 241s 5s/step - loss: 0.1081
# Epoch 23/100
# 51/51 [==============================] - 241s 5s/step - loss: 0.1061
# Epoch 24/100
# 51/51 [==============================] - 242s 5s/step - loss: 0.1036
# Epoch 25/100
# 51/51 [==============================] - 242s 5s/step - loss: 0.0976
# Epoch 26/100
# 51/51 [==============================] - 242s 5s/step - loss: 0.0997
# Epoch 27/100
# 51/51 [==============================] - 240s 5s/step - loss: 0.0950
# Epoch 28/100
# 51/51 [==============================] - 240s 5s/step - loss: 0.0922
# Epoch 29/100
# 51/51 [==============================] - 240s 5s/step - loss: 0.0934
# Epoch 30/100
# 51/51 [==============================] - 239s 5s/step - loss: 0.0921
# Epoch 31/100
# 51/51 [==============================] - 241s 5s/step - loss: 0.0901
# Epoch 32/100
# 51/51 [==============================] - 241s 5s/step - loss: 0.0899
# Epoch 33/100
# 51/51 [==============================] - 241s 5s/step - loss: 0.0865
# Epoch 34/100
# 51/51 [==============================] - 252s 5s/step - loss: 0.0889
# Epoch 35/100
# 51/51 [==============================] - 239s 5s/step - loss: 0.0881
# Epoch 36/100
# 51/51 [==============================] - 239s 5s/step - loss: 0.0910
# Epoch 37/100
# 51/51 [==============================] - 240s 5s/step - loss: 0.0889
# Epoch 38/100
# 51/51 [==============================] - 242s 5s/step - loss: 0.0859
# Epoch 39/100
# 51/51 [==============================] - 242s 5s/step - loss: 0.0877
# Epoch 40/100
# 51/51 [==============================] - 242s 5s/step - loss: 0.0874
# Epoch 41/100
# 51/51 [==============================] - 244s 5s/step - loss: 0.0856
# Epoch 42/100
# 51/51 [==============================] - 242s 5s/step - loss: 0.0872
# Epoch 43/100
# 51/51 [==============================] - 240s 5s/step - loss: 0.0871
# Epoch 44/100
# 51/51 [==============================] - 241s 5s/step - loss: 0.0879
# Epoch 45/100
# 51/51 [==============================] - 239s 5s/step - loss: 0.0884
# Epoch 46/100
# 51/51 [==============================] - 241s 5s/step - loss: 0.0855
# Epoch 47/100
# 51/51 [==============================] - 240s 5s/step - loss: 0.0843
# Epoch 48/100
# 51/51 [==============================] - 238s 5s/step - loss: 0.0864
# Epoch 49/100
# 51/51 [==============================] - 241s 5s/step - loss: 0.0903
# Epoch 50/100
# 51/51 [==============================] - 239s 5s/step - loss: 0.0848
# Epoch 51/100
#  3/51 [>.............................] - ETA: 3:42 - loss: 0.0967

# %%
tf.train.latest_checkpoint(checkpoint_dir)
# Out:
# '/content/gdrive/My Drive/training_checkpoints/simple/weights.15-0.15'

# %%
model = build_model(vocab_size, embedding_dim, rnn_units, batch_size=1)

model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))

model.build(tf.TensorShape([1, None]))

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (1, None, 50)             91200
# _________________________________________________________________
# gru_18 (GRU)                 (1, None, 1024)           3302400
# _________________________________________________________________
# gru_19 (GRU)                 (1, None, 1024)           6294528
# _________________________________________________________________
# gru_20 (GRU)                 (1, None, 1024)           6294528
# _________________________________________________________________
# dense_6 (Dense)              (1, None, 1824)           1869600
# =================================================================
# Total params: 17,852,256
# Trainable params: 17,852,256
# Non-trainable params: 0
# _________________________________________________________________

# %%
def generate_text(model, start_string):
    # Evaluation step (generating text using the learned model)

    # Number of characters to generate
    num_generate = 10

    # Converting ur start string to numbers (vectorizing) 
    input_eval = [char2idx[s] for s in start_string.split()]
    input_eval = tf.expand_dims(input_eval, 0)

    # Empty string to store our results
    text_generated = []

    # Low temperatures results in more predictable text.
    # Higher temperatures results in more surprising text.
    # Experiment to find the best setting.
    temperature = 1

    # Here batch size == 1
    model.reset_states()
    for i in range(num_generate):
        predictions = model(input_eval)
        # remove the batch dimension
        predictions = tf.squeeze(predictions, 0)

        # using a multinomial distribution to predict the word returned by the model
        predictions = predictions / temperature
        predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()

        # We pass the predicted word as the next input to the model
        # along with the previous hidden state
        input_eval = tf.expand_dims([predicted_id], 0)

        text_generated.append(idx2char[predicted_id])

    return (start_string + ' ' + ' '.join(text_generated))

# %%
for i in range(10):
  print(generate_text(model, start_string=u"hunter"))
# Out:
# hunter histori amp fan like sum perfectli great sposwrit rip gerri
# hunter tour sunday stop st loui houston dalla see play time
# hunter histori amp fan like sum perfectli great sposwrit rip gerri
# hunter breakthrough group front offic turn proud franchis joke good morn
# hunter histori amp fan like sum perfectli great sposwrit rip gerri
# hunter choic tix dont know run twitter account like make day
# hunter histori great amp play ranger ray tie bottom 2nd adrian
# hunter penc 30th unt night globe life park first ticket purchas
# hunter histori amp fan like sum perfectli great sposwrit rip couldnt
# hunter histori amp fan like sum perfectli great sposwrit rip gerri

# %%
# %ls
# Out:
# gdrive/  sample_data/

# %%
# %cd training_checkpoints/simple/
# Out:
# /content/gdrive/My Drive/training_checkpoints/simple

# %%
# %rm -rf *
